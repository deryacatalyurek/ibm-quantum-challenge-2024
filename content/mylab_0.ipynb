# %%
# !pip install qiskit[visualization]==1.0.2
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from qiskit import QuantumCircuit

qc = QuantumCircuit(1) #Create a new circuit with a single qubit
qc.x(0) #Add a NOT gate to qubit 0

qc.draw("mpl")

# %%
### Install the other required packages as well

# !pip install qiskit_aer
# !pip install qiskit_ibm_runtime
# !pip install matplotlib
# !pip install pylatexenc
# !pip install qiskit-transpiler-service
# !pip install git+https://github.com/qiskit-community/Quantum-Challenge-Grader.git
# Out:
# ...
#      ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.5 MB 1.3 MB/s eta 0:00:08
#      ---------------------------------------- 0.1/9.5 MB 812.7 kB/s eta 0:00:12
#      ---------------------------------------- 0.1/9.5 MB 744.7 kB/s eta 0:00:13
#       --------------------------------------- 0.2/9.5 MB 1.3 MB/s eta 0:00:08
#       --------------------------------------- 0.2/9.5 MB 1.1 MB/s eta 0:00:09
#      - -------------------------------------- 0.3/9.5 MB 1.3 MB/s eta 0:00:08
#      - -------------------------------------- 0.3/9.5 MB 1.0 MB/s eta 0:00:10
#      - -------------------------------------- 0.5/9.5 MB 1.4 MB/s eta 0:00:07
#      -- ------------------------------------- 0.5/9.5 MB 1.5 MB/s eta 0:00:07
#      -- ------------------------------------- 0.6/9.5 MB 1.5 MB/s eta 0:00:06
#      --- ------------------------------------ 0.8/9.5 MB 1.7 MB/s eta 0:00:06
# ...

# %%
import qiskit
qiskit.__version__
# Out:
# '1.0.2'

# %%
# %set_env QXToken=35a3d6b35d8e30186b02ceed627b2c9aab90a321c752a9432b93f37a3b1dc933bda63792735bc95754b5fb28f0301b31ab290258d0a23bdccd1a75e10fb9eb8e
# Out:
# env: QXToken=35a3d6b35d8e30186b02ceed627b2c9aab90a321c752a9432b93f37a3b1dc933bda63792735bc95754b5fb28f0301b31ab290258d0a23bdccd1a75e10fb9eb8e

# %%
### Imports

from qiskit import QuantumCircuit
from qiskit.quantum_info import SparsePauliOp
from qiskit_ibm_runtime import EstimatorV2 as Estimator
from qiskit_aer import AerSimulator
import matplotlib.pyplot as plt
from qc_grader.challenges.iqc_2024 import grade_lab0_ex1

# %%
qc = QuantumCircuit(2)

qc.h(0) #Apply Hadamard to qubit 0
qc.cx(0, 1) #Perform a CNOT gate on qubit 1, control qubit 0 
qc.draw("mpl")

# %%
#First Task 
# The ZZ applies a Z operator on qubit 0, and a Z operator on qubit 1
ZZ = SparsePauliOp('ZZ')

# The ZI applies a Z operator on qubit 0, and an Identity operator on qubit 1
ZI = SparsePauliOp('ZI')

# The IX applies an Identity operator on qubit 0, and an X operator on qubit 1
IX = SparsePauliOp('IX')

### Write your code below here ###
### Follow the same naming convention we used above

#Applies an Identity on qubit 0, Z operator on qubit 1
IZ = SparsePauliOp('IZ')

#Applies X operator on qubit 0, Identity operator on qubit 1
XI = SparsePauliOp('XI')

#Applies X on both qubits 
XX = SparsePauliOp('XX')


## Don't change any code past this line, but remember to run the cell.

observables = [IZ, IX, ZI, XI, ZZ, XX]

# %%
grade_lab0_ex1(observables)
# Out:
# Submitting your answer. Please wait...
# Congratulations 🎉! Your answer is correct and has been submitted.

# %%
# Set up the Estimator
estimator = Estimator(backend=AerSimulator())

# Submit the circuit to Estimator
pub = (qc, observables)

job = estimator.run(pubs=[pub])

# %%
#Collect data 
data = ['IZ', 'IX', 'ZI', 'XI', 'ZZ', 'XX']
values = job.result()[0].data.evs

# Set up our graph
container = plt.plot(data, values, '-o')

# Label each axis
plt.xlabel('Observables')
plt.ylabel('Values')

plt.show() #Draw final graph

# %%
container = plt.bar(data, values, width=0.8)

plt.xlabel('Observables')
plt.ylabel('Values')

plt.show()
